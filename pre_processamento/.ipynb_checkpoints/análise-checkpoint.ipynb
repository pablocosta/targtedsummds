# %%
import pandas as pd
from tqdm._tqdm_notebook import tqdm_notebook
tqdm_notebook.pandas()

# %%
df = pd.read_csv("../corpus/B2W-Reviews01.csv", sep=";")
print(df.shape)
# Out:
# (132373, 14)

# %%
df = df.drop(["submission_date", "recommend_to_a_friend"], axis=1)
df["reviewer_birth_year"] = df["reviewer_birth_year"].fillna(value= 1900)

# %%
df["site_category_lv1"].value_counts(dropna=False).plot(kind="bar", figsize=(10,10))

# %%
orig = df.shape[0]
df = df.dropna(subset=["reviewer_gender"])
print(orig - df.shape[0], "valores dropados")
df["reviewer_gender"].value_counts(dropna=False).plot(kind="bar")
# Out:
# 4136 valores dropados

# %%
df['reviewer_birth_year'].value_counts(dropna=False)
# Out:
# 1981.0    4347
# 1982.0    4346
# 1983.0    4213
# 1984.0    4206
# 1980.0    4126
#           ...
# 1914.0       1
# 1915.0       1
# 1916.0       1
# 1917.0       1
# 1926.0       1
# Name: reviewer_birth_year, Length: 115, dtype: int64

# %%
df["reviewer_state"].value_counts(dropna=False).plot(kind="bar", figsize=(10,10))

# %%
counts = df['reviewer_birth_year'].value_counts()

res = df[df['reviewer_birth_year'].isin(counts[counts < 40].index)]
orig = df.shape[0]
df = df.drop(res['reviewer_birth_year'].dropna().index)

print(orig - df.shape[0], "Valores removidos")
# Out:
# 0 Valores removidos

# %%
counts = df['reviewer_state'].value_counts()

res = df[df['reviewer_state'].isin(counts[counts < 1000].index)]
orig = df.shape[0]
df = df.drop(res['reviewer_state'].dropna().index)

print(orig - df.shape[0], "Valores removidos")
# Out:
# 6779 Valores removidos

# %%
df["reviewer_state"].value_counts(dropna=False).plot(kind="bar", figsize=(10,10))

# %%
df = df.drop(["reviewer_id", "product_id", "product_name", "product_brand", "site_category_lv1", 
         "site_category_lv2", "overall_rating"], axis=1)

# %%
import string
import spacy
import re

nlp = spacy.load("pt_core_news_sm")

punctuations = string.punctuation



def tokenize(text, logging=False):
    tokens = [tok.lemma_.lower().strip() for tok in nlp(text)]
    
    return " ".join(tokens)

# %%
df["review_text"] = df["review_text"].progress_apply(lambda x : tokenize(x))
df["review_title"] = df["review_title"].progress_apply(lambda x : tokenize(x))
# Out:
# HBox(children=(IntProgress(value=0, max=121141), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=121141), HTML(value='')))

# %%
#removemos sentencas a serem geradsa maiores que 10
#removemos sentencas a serem analisadas maiores que 30
df.shape
df = df[df['review_text'].str.split(" ").str.len().lt(30)]
df = df[df['review_title'].str.split(" ").str.len().lt(10)]
df.shape
# Out:
# (84519, 5)

# %%
df["size"] = df["review_text"].apply(lambda x : filter_string(x))
df["size"].describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-29f5122f17ed> in <module>
# ----> 1 df["size"] = df["review_text"].apply(lambda x : filter_string(x))
#       2 df["size"].describe()
#
# ~/.conda/envs/torch/lib/python3.7/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    3192             else:
#    3193                 values = self.astype(object).values
# -> 3194                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3195
#    3196         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/src/inference.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-19-29f5122f17ed> in <lambda>(x)
# ----> 1 df["size"] = df["review_text"].apply(lambda x : filter_string(x))
#       2 df["size"].describe()
#
# NameError: name 'filter_string' is not defined

# %%
def clean_text(text, logging=False):
    """ 
        TEMOS QUE REMOVER A PONTUACAO, PRONOMES E SIMBOLOS DE REAIS.
        SUBSTITUIR NÚMEROS PRLO TOKEN <NUM> 
        
    """
    
    #tokens = [tok.lemma_.lower().strip() for tok in nlp(text) if not(tok.is_stop)]
    tokens = text.split(" ")
    tokens = [tok for tok in tokens if tok not in punctuations]
    tokens = [re.sub('\r$', '', tok) for tok in tokens]
    tokens = ' '.join(tokens)
    toks   = []
    for tok in nlp(tokens):
        if tok.pos_ == 'NUM':
            toks.append("<num>".lower().strip())
        else:
            toks.append(tok.lemma_.lower().strip())
            
        
    #tokens = [tok.pos_ for tok in nlp(tokens) if tok.pos_ == 'NUM' else str(tok)]

    return " ".join(toks)

df["review_text"] = df["review_text"].progress_apply(lambda x : clean_text(x))
df["review_title"] = df["review_title"].progress_apply(lambda x : clean_text(x))
# Out:
# HBox(children=(IntProgress(value=0, max=84519), HTML(value='')))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-a9bcca2514f2> in <module>
#      23     return " ".join(toks)
#      24
# ---> 25 df["review_text"] = df["review_text"].progress_apply(lambda x : clean_text(x))
#      26 df["review_title"] = df["review_title"].progress_apply(lambda x : clean_text(x))
#
# ~/.conda/envs/torch/lib/python3.7/site-packages/tqdm/_tqdm.py in inner(df, func, *args, **kwargs)
#     668                 # Apply the provided function (in **kwargs)
#     669                 # on the df using our wrapper (which provides bar updating)
# --> 670                 result = getattr(df, df_function)(wrapper, **kwargs)
#     671
#     672                 # Close bar and return pandas calculation result
#
# ~/.conda/envs/torch/lib/python3.7/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    3192             else:
#    3193                 values = self.astype(object).values
# -> 3194                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3195
#    3196         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/src/inference.pyx in pandas._libs.lib.map_infer()
#
# ~/.conda/envs/torch/lib/python3.7/site-packages/tqdm/_tqdm.py in wrapper(*args, **kwargs)
#     664                     # take a fast or slow code path; so stop when t.total==t.n
#     665                     t.update(n=1 if not t.total or t.n < t.total else 0)
# --> 666                     return func(*args, **kwargs)
#     667
#     668                 # Apply the provided function (in **kwargs)
#
# <ipython-input-20-a9bcca2514f2> in <lambda>(x)
#      23     return " ".join(toks)
#      24
# ---> 25 df["review_text"] = df["review_text"].progress_apply(lambda x : clean_text(x))
#      26 df["review_title"] = df["review_title"].progress_apply(lambda x : clean_text(x))
#
# <ipython-input-20-a9bcca2514f2> in clean_text(text, logging)
#      12     tokens = ' '.join(tokens)
#      13     toks   = []
# ---> 14     for tok in nlp(tokens):
#      15         if tok.pos_ == 'NUM':
#      16             toks.append("<num>".lower().strip())
#
# ~/.conda/envs/torch/lib/python3.7/site-packages/spacy/language.py in __call__(self, text, disable, component_cfg)
#     383             if not hasattr(proc, "__call__"):
#     384                 raise ValueError(Errors.E003.format(component=type(proc), name=name))
# --> 385             doc = proc(doc, **component_cfg.get(name, {}))
#     386             if doc is None:
#     387                 raise ValueError(Errors.E005.format(name=name))
#
# nn_parser.pyx in spacy.syntax.nn_parser.Parser.__call__()
#
# nn_parser.pyx in spacy.syntax.nn_parser.Parser.predict()
#
# nn_parser.pyx in spacy.syntax.nn_parser.Parser.greedy_parse()
#
# ~/.conda/envs/torch/lib/python3.7/site-packages/thinc/neural/_classes/model.py in __call__(self, x)
#     163             Must match expected shape
#     164         """
# --> 165         return self.predict(x)
#     166
#     167     def pipe(self, stream, batch_size=128):
#
# ~/.conda/envs/torch/lib/python3.7/site-packages/thinc/neural/_classes/model.py in predict(self, X)
#     127
#     128     def predict(self, X):
# --> 129         y, _ = self.begin_update(X, drop=None)
#     130         return y
#     131
#
# _parser_model.pyx in spacy.syntax._parser_model.ParserModel.begin_update()
#
# _parser_model.pyx in spacy.syntax._parser_model.ParserStepModel.__init__()
#
# ~/.conda/envs/torch/lib/python3.7/site-packages/thinc/neural/_classes/feed_forward.py in begin_update(self, X, drop)
#      44         callbacks = []
#      45         for layer in self._layers:
# ---> 46             X, inc_layer_grad = layer.begin_update(X, drop=drop)
#      47             callbacks.append(inc_layer_grad)
#      48
#
# ~/.conda/envs/torch/lib/python3.7/site-packages/thinc/api.py in begin_update(seqs_in, drop)
#     262     def begin_update(seqs_in, drop=0.0):
#     263         lengths = layer.ops.asarray([len(seq) for seq in seqs_in])
# --> 264         X, bp_layer = layer.begin_update(layer.ops.flatten(seqs_in, pad=pad), drop=drop)
#     265         if bp_layer is None:
#     266             return layer.ops.unflatten(X, lengths, pad=pad), None
#
# ~/.conda/envs/torch/lib/python3.7/site-packages/thinc/neural/_classes/feed_forward.py in begin_update(self, X, drop)
#      44         callbacks = []
#      45         for layer in self._layers:
# ---> 46             X, inc_layer_grad = layer.begin_update(X, drop=drop)
#      47             callbacks.append(inc_layer_grad)
#      48
#
# ~/.conda/envs/torch/lib/python3.7/site-packages/thinc/neural/_classes/resnet.py in begin_update(self, X, drop)
#      19
#      20     def begin_update(self, X, drop=0.0):
# ---> 21         y, bp_y = self._layers[0].begin_update(X, drop=drop)
#      22         if isinstance(X, list) or isinstance(X, tuple):
#      23             output = [X[i] + y[i] for i in range(len(X))]
#
# ~/.conda/envs/torch/lib/python3.7/site-packages/thinc/neural/_classes/feed_forward.py in begin_update(self, X, drop)
#      44         callbacks = []
#      45         for layer in self._layers:
# ---> 46             X, inc_layer_grad = layer.begin_update(X, drop=drop)
#      47             callbacks.append(inc_layer_grad)
#      48
#
# ~/.conda/envs/torch/lib/python3.7/site-packages/thinc/neural/_classes/layernorm.py in begin_update(self, X, drop)
#      53
#      54     def begin_update(self, X, drop=0.0):
# ---> 55         X, backprop_child = self.child.begin_update(X, drop=0.0)
#      56         N, mu, var = _get_moments(self.ops, X)
#      57
#
# ~/.conda/envs/torch/lib/python3.7/site-packages/thinc/neural/_classes/maxout.py in begin_update(self, X__bi, drop)
#      74         if drop is not None:
#      75             drop *= self.drop_factor
# ---> 76         output__boc = self.ops.gemm(X__bi, W, trans2=True)
#      77         output__boc += self.b.reshape((self.nO * self.nP,))
#      78         output__boc = output__boc.reshape((output__boc.shape[0], self.nO, self.nP))
#
# KeyboardInterrupt:

# %%
df["reviewer_birth_year"] = 2020 - df["reviewer_birth_year"]
df = df[df["reviewer_birth_year"] != 120.0] # é um oulier
df["reviewer_birth_year"].describe()
# Out:
# count    83226.000000
# mean        42.757516
# std         12.659801
# min         18.000000
# 25%         33.000000
# 50%         41.000000
# 75%         51.000000
# max         84.000000
# Name: reviewer_birth_year, dtype: float64

# %%
df = df.dropna(subset=["review_text"])
df.shape
# Out:
# (83226, 5)

# %%
df.to_csv("post_processed.csv", sep="\t", index=False)

# %%
text_complex = open("./complex.txt", "w+")
for ele in df["review_text"].tolist():
    if len(ele.split(" ")) <= 30:
        for word in ele.split(" "):
            text_complex.write(word+" ")
        text_complex.write("\n\n")


text_complex.close()

# %%
text_complex = open("./title.txt", "w+")
for ele in df["review_title"].tolist():
    if len(ele.split(" ")) <= 30:
        for word in ele.split(" "):
            text_complex.write(word+" ")
        text_complex.write("\n\n")


text_complex.close()

# %%
df = pd.read_csv("post_processed.csv", sep="\t")

# %%
df["reviewer_birth_year"] = 2019 - df["reviewer_birth_year"]

# %%
df = df[df["reviewer_birth_year"] != 119.0] # é um oulier

# %%
df["reviewer_birth_year"].value_counts().plot(kind="bar", figsize=(20,10))

# %%
df.shape
# Out:
# (83226, 5)

# %%
df.to_csv("post_processed.csv", sep="\t")

# %%
df = pd.read_csv("post_processed.csv", sep="\t")
df['age_bins'] = pd.cut(x=df['reviewer_birth_year'], bins=[26, 36, 46, 56, 66])
df.shape
# Out:
# (83226, 7)

# %%
df['age_bins']
# Out:
# 0             NaN
# 1             NaN
# 2        (26, 36]
# 3        (26, 36]
# 4        (26, 36]
# 5        (26, 36]
# 6             NaN
# 7        (36, 46]
# 8        (46, 56]
# 9             NaN
# 10       (36, 46]
# 11       (26, 36]
# 12       (26, 36]
# 13       (26, 36]
# 14       (36, 46]
# 15       (46, 56]
# 16       (26, 36]
# 17       (26, 36]
# 18       (26, 36]
# 19       (46, 56]
# 20       (36, 46]
# 21            NaN
# 22       (26, 36]
# 23       (36, 46]
# 24       (36, 46]
# 25       (36, 46]
# 26       (26, 36]
# 27       (26, 36]
# 28            NaN
# 29            NaN
#            ...
# 83196    (36, 46]
# 83197         NaN
# 83198         NaN
# 83199    (36, 46]
# 83200         NaN
# 83201         NaN
# 83202    (36, 46]
# 83203    (36, 46]
# 83204    (36, 46]
# 83205    (36, 46]
# 83206    (36, 46]
# 83207    (36, 46]
# 83208    (36, 46]
# 83209         NaN
# 83210         NaN
# 83211         NaN
# 83212         NaN
# 83213    (36, 46]
# 83214    (46, 56]
# 83215    (26, 36]
# 83216         NaN
# 83217    (36, 46]
# 83218    (36, 46]
# 83219    (46, 56]
# 83220    (36, 46]
# 83221    (26, 36]
# 83222    (36, 46]
# 83223    (36, 46]
# 83224    (26, 36]
# 83225    (36, 46]
# Name: age_bins, Length: 83226, dtype: category
# Categories (3, interval[int64]): [(26, 36] < (36, 46] < (46, 56]]

# %%
#df = df[pd.notnull(df['Gender'])]

df = df.dropna(subset=["age_bins"], axis=0)

df = df.dropna(subset=["review_title"], axis=0)

# %%
df['age_bins']

# %%
df.shape

# %%
df_.to_csv("post_processed.csv", sep="\t")

# %%
df = pd.read_csv("post_processed.csv", sep="\t")
text_complex = open("./complex.txt", "w+")
for ele in df["review_text"].tolist():
    for word in ele.split(" "):
        text_complex.write(word+" ")
    text_complex.write("\n\n")


text_complex.close()

# %%
text_complex = open("./title.txt", "w+")
for ele in df["review_title"].tolist():
    for word in ele.split(" "):
        text_complex.write(word+" ")
    text_complex.write("\n\n")


text_complex.close()
